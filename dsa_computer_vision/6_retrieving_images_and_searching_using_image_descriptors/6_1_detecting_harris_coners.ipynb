# %% [markdown]
# ##  Detecting Harris corners
#
# The Harris is a detection algorithm

# %%
import os
from pathlib import Path

# Função para detectar a raiz do projeto com base na presença de ".venv"
def find_project_root(max_depth=10):
    # Ativa autoreload para desenvolvimento dinâmico
    # %load_ext autoreload
    # %autoreload 2
    current = Path.cwd()
    for i in range(max_depth):
        if any((current / name).exists() for name in [".venv", "pyproject.toml", ".git"]):
            print(f"📁 Raiz do projeto encontrada: {current}")
            os.chdir(current)
            return current
        print(f"{i} - Subindo para: {current.parent}")
        current = current.parent
    raise RuntimeError("❌ Raiz do projeto não encontrada.")

project_root = find_project_root()
# Out:
# 0 - Subindo para: g:\py_projects\computer-vision\dsa_computer_vision
# 1 - Subindo para: g:\py_projects\computer-vision
# 📁 Raiz do projeto encontrada: g:\py_projects\computer-vision

# %%
# The Sobel operator detects edges by measuring horizontal and
 # vertical differences between pixel values in a neighborhood, and it does this using a kernel.

# The cv2.cornerHarris function uses a Sobel operator whose aperture is defined by this
#  parameter


import cv2
img = cv2.imread('data/images_1/chess_board.png')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Each value in this image represents a score for the corresponding pixel in the source image
dst = cv2.cornerHarris(src=gray, blockSize=2, ksize=23, k=0.04)
img[dst > 0.01 * dst.max()] = [0, 0, 255]
cv2.imshow('corners', img)
cv2.waitKey()
# Out:
# -1

# %% [markdown]
# ## Detecting DoG features and extracting SIFT descriptors

# %%
import cv2
img = cv2.imread('data/images_1/varese.jpg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# sift = cv2.xfeatures2d.SIFT_create()
sift = cv2.SIFT_create()

keypoints, descriptors = sift.detectAndCompute(gray, None)

cv2.drawKeypoints(img, keypoints, img, (51, 163, 236),
                cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
                
cv2.imshow('sift_keypoints', img)
cv2.waitKey()
# Out:
# -1

# %%
cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS
# Out:
# 2
